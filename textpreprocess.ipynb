# %%
import pandas as pd
import nltk
import string

# %%
df = pd.read_csv('AllTweets.csv')
df.head(10)
# Out:
#    Unnamed: 0.1  Unnamed: 0  ix               date            id  \
# 0             0           0   0    18h18 hours ago  7.870000e+17
# 1             1           1   1    19h19 hours ago  7.870000e+17
# 2             2           2   2    17h17 hours ago  7.870000e+17
# 3             3           3   3  47m47 minutes ago  7.870000e+17
# 4             4           4   4    24h24 hours ago  7.870000e+17
# 5             5           5   5    20h20 hours ago  7.870000e+17
# 6             6           6   6    21h21 hours ago  7.870000e+17
# 7             7           7   7    22h22 hours ago  7.870000e+17
# 8             8           8   8    23h23 hours ago  7.870000e+17
# 9             9           9   9             13-Oct  7.870000e+17
#
#                               link  retweet  \
# 0  /NASA/status/787029214612586496    False
# 1  /NASA/status/787008587927281664    False
# 2  /NASA/status/787042156116664320    False
# 3  /NASA/status/787284414732472320    False
# ...

# %%
df['clean_text']=df['text'].str.lower()
df.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0  ix               date            id  \
# 0             0           0   0    18h18 hours ago  7.870000e+17
# 1             1           1   1    19h19 hours ago  7.870000e+17
# 2             2           2   2    17h17 hours ago  7.870000e+17
# 3             3           3   3  47m47 minutes ago  7.870000e+17
# 4             4           4   4    24h24 hours ago  7.870000e+17
#
#                               link  retweet  \
# 0  /NASA/status/787029214612586496    False
# 1  /NASA/status/787008587927281664    False
# 2  /NASA/status/787042156116664320    False
# 3  /NASA/status/787284414732472320    False
# 4  /NASA/status/786934496625102848    False
#
#                                                 text author
# 0  software spacestation communications faster ea...   NASA
# 1  ready orbitalatks antares rocket cargo ship se...   NASA
# 2  rocket 803pm et sunday deliver cargo spacestat...   NASA
# 3  happened week potus outlined explorations futu...   NASA
# ...

# %%
nltk.download('stopwords')
from nltk.corpus import stopwords
stop_words = stopwords.words('english')
# Out:
# [nltk_data] Error loading stopwords: <urlopen error [WinError 10060] A
# [nltk_data]     connection attempt failed because the connected party
# [nltk_data]     did not properly respond after a period of time, or
# [nltk_data]     established connection failed because connected host
# [nltk_data]     has failed to respond>

# %%
def remove_stop(x):    
    return " ".join([word for word in str(x).split() if word not in stop_words])
df['clean_text']=df['text'].apply(lambda x : remove_stop(x))

# %%
df.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0  ix               date            id  \
# 0             0           0   0    18h18 hours ago  7.870000e+17
# 1             1           1   1    19h19 hours ago  7.870000e+17
# 2             2           2   2    17h17 hours ago  7.870000e+17
# 3             3           3   3  47m47 minutes ago  7.870000e+17
# 4             4           4   4    24h24 hours ago  7.870000e+17
#
#                               link  retweet  \
# 0  /NASA/status/787029214612586496    False
# 1  /NASA/status/787008587927281664    False
# 2  /NASA/status/787042156116664320    False
# 3  /NASA/status/787284414732472320    False
# 4  /NASA/status/786934496625102848    False
#
#                                                 text author
# 0  software spacestation communications faster ea...   NASA
# 1  ready orbitalatks antares rocket cargo ship se...   NASA
# 2  rocket 803pm et sunday deliver cargo spacestat...   NASA
# 3  happened week potus outlined explorations futu...   NASA
# ...

# %%
punct = string.punctuation

# %%
def remove_punctuation(x):
    return (x.translate(str.maketrans("","",punct)))
df['clean_text']= df['text'].apply(lambda x:remove_punctuation(x))

# %%
df.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0  ix               date            id  \
# 0             0           0   0    18h18 hours ago  7.870000e+17
# 1             1           1   1    19h19 hours ago  7.870000e+17
# 2             2           2   2    17h17 hours ago  7.870000e+17
# 3             3           3   3  47m47 minutes ago  7.870000e+17
# 4             4           4   4    24h24 hours ago  7.870000e+17
#
#                               link  retweet  \
# 0  /NASA/status/787029214612586496    False
# 1  /NASA/status/787008587927281664    False
# 2  /NASA/status/787042156116664320    False
# 3  /NASA/status/787284414732472320    False
# 4  /NASA/status/786934496625102848    False
#
#                                                 text author
# 0  software spacestation communications faster ea...   NASA
# 1  ready orbitalatks antares rocket cargo ship se...   NASA
# 2  rocket 803pm et sunday deliver cargo spacestat...   NASA
# 3  happened week potus outlined explorations futu...   NASA
# ...

# %%
from collections import Counter
cnt = Counter()
for text in df['text'].values:
    for word in text.split():
        cnt[word]+=1
cnt.most_common(50)
# Out:
# [('want', 1325),
#  ('years', 1320),
#  ('earth', 1302),
#  ('thanks', 1292),
#  ('cant', 1288),
#  ('much', 1278),
#  ('u', 1271),
#  ('work', 1258),
#  ('night', 1257),
#  ('take', 1256),
#  ('never', 1245),
#  ('2', 1228),
#  ('et', 1227),
#  ('right', 1225),
#  ('world', 1212),
#  ('going', 1196),
#  ('thank', 1174),
#  ('spacestation', 1166),
#  ('happy', 1159),
#  ('learning', 1148),
#  ('shuttle', 1124),
#  ('check', 1121),
#  ('many', 1118),
#  ('image', 1114),
#  ('country', 1106),
#  ('better', 1103),
#  ('way', 1097),
#  ('donald', 1095),
#  ('really', 1088),
#  ('year', 1087),
#  ('kdn', 1076),
#  ('–', 1065),
#  ('1', 1047),
#  ('ever', 1043),
#  ('show', 1037),
#  ('could', 1027),
#  ('10', 1022),
#  ('next', 1021),
#  ('got', 1003),
#  ('every', 997),
#  ('—president', 994),
#  ('vote', 992),
#  ('crew', 980),
#  ('help', 960),
#  ('americans', 955),
#  ('tv', 945),
#  ('mission', 941),
#  ('news', 927),
#  ('still', 922),
#  ('made', 912)]

# %%
#freq_words=set([w for (w,wc) in cnt.most_common(50)])
#freq_words

# %%
#def remove_freq(x):
#    return " ".join([word for word in str(x).split() if word not in freq_words])

#df['text']= df['text'].apply(lambda x: remove_freq(x))

# %%
df.head(10)
# Out:
#    Unnamed: 0.1  Unnamed: 0  ix               date            id  \
# 0             0           0   0    18h18 hours ago  7.870000e+17
# 1             1           1   1    19h19 hours ago  7.870000e+17
# 2             2           2   2    17h17 hours ago  7.870000e+17
# 3             3           3   3  47m47 minutes ago  7.870000e+17
# 4             4           4   4    24h24 hours ago  7.870000e+17
# 5             5           5   5    20h20 hours ago  7.870000e+17
# 6             6           6   6    21h21 hours ago  7.870000e+17
# 7             7           7   7    22h22 hours ago  7.870000e+17
# 8             8           8   8    23h23 hours ago  7.870000e+17
# 9             9           9   9             13-Oct  7.870000e+17
#
#                               link  retweet  \
# 0  /NASA/status/787029214612586496    False
# 1  /NASA/status/787008587927281664    False
# 2  /NASA/status/787042156116664320    False
# 3  /NASA/status/787284414732472320    False
# ...

# %%
df1=df

# %%
df1.to_csv('AllTweets10.csv')
